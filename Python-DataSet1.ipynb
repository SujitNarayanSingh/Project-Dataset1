# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('India GDP 1960-2022.csv')

# %%
df
# Out:
#     Unnamed: 0 India GDP - Historical Data India GDP - Historical Data.1  \
# 0          NaN                        Year                           GDP
# 1          0.0                        2021                    $3,173.40B
# 2          1.0                        2020                    $2,667.69B
# 3          2.0                        2019                    $2,831.55B
# 4          3.0                        2018                    $2,702.93B
# ..         ...                         ...                           ...
# 58        57.0                        1964                       $56.48B
# 59        58.0                        1963                       $48.42B
# 60        59.0                        1962                       $42.16B
# 61        60.0                        1961                       $39.23B
# 62        61.0                        1960                       $37.03B
#
#    India GDP - Historical Data.2 India GDP - Historical Data.3
# 0                     Per Capita                        Growth
# 1                         $2,277                         8.95%
# 2                         $1,933                        -6.60%
# 3                         $2,072                         3.74%
# 4                         $1,998                         6.45%
# ..                           ...                           ...
# 58                          $116                         7.45%
# 59                          $101                         5.99%
# 60                           $90                         2.93%
# 61                           $85                         3.72%
# 62                           $82                             %
#
# [63 rows x 5 columns]

# %%
df.head()
# Out:
#    Unnamed: 0 India GDP - Historical Data India GDP - Historical Data.1  \
# 0         NaN                        Year                           GDP
# 1         0.0                        2021                    $3,173.40B
# 2         1.0                        2020                    $2,667.69B
# 3         2.0                        2019                    $2,831.55B
# 4         3.0                        2018                    $2,702.93B
#
#   India GDP - Historical Data.2 India GDP - Historical Data.3
# 0                    Per Capita                        Growth
# 1                        $2,277                         8.95%
# 2                        $1,933                        -6.60%
# 3                        $2,072                         3.74%
# 4                        $1,998                         6.45%

# %%
df.tail()
# Out:
#     Unnamed: 0 India GDP - Historical Data India GDP - Historical Data.1  \
# 58        57.0                        1964                       $56.48B
# 59        58.0                        1963                       $48.42B
# 60        59.0                        1962                       $42.16B
# 61        60.0                        1961                       $39.23B
# 62        61.0                        1960                       $37.03B
#
#    India GDP - Historical Data.2 India GDP - Historical Data.3
# 58                          $116                         7.45%
# 59                          $101                         5.99%
# 60                           $90                         2.93%
# 61                           $85                         3.72%
# 62                           $82                             %

# %%
df.head(10)
# Out:
#    Unnamed: 0 India GDP - Historical Data India GDP - Historical Data.1  \
# 0         NaN                        Year                           GDP
# 1         0.0                        2021                    $3,173.40B
# 2         1.0                        2020                    $2,667.69B
# 3         2.0                        2019                    $2,831.55B
# 4         3.0                        2018                    $2,702.93B
# 5         4.0                        2017                    $2,651.47B
# 6         5.0                        2016                    $2,294.80B
# 7         6.0                        2015                    $2,103.59B
# 8         7.0                        2014                    $2,039.13B
# 9         8.0                        2013                    $1,856.72B
#
#   India GDP - Historical Data.2 India GDP - Historical Data.3
# 0                    Per Capita                        Growth
# 1                        $2,277                         8.95%
# 2                        $1,933                        -6.60%
# 3                        $2,072                         3.74%
# 4                        $1,998                         6.45%
# 5                        $1,981                         6.80%
# 6                        $1,733                         8.26%
# 7                        $1,606                         8.00%
# 8                        $1,574                         7.41%
# 9                        $1,450                         6.39%

# %%
df.tail(10)
# Out:
#     Unnamed: 0 India GDP - Historical Data India GDP - Historical Data.1  \
# 53        52.0                        1969                       $58.45B
# 54        53.0                        1968                       $53.09B
# 55        54.0                        1967                       $50.13B
# 56        55.0                        1966                       $45.87B
# 57        56.0                        1965                       $59.55B
# 58        57.0                        1964                       $56.48B
# 59        58.0                        1963                       $48.42B
# 60        59.0                        1962                       $42.16B
# 61        60.0                        1961                       $39.23B
# 62        61.0                        1960                       $37.03B
#
#    India GDP - Historical Data.2 India GDP - Historical Data.3
# 53                          $108                         6.54%
# 54                          $100                         3.39%
# 55                           $96                         7.83%
# 56                           $90                        -0.06%
# 57                          $119                        -2.64%
# 58                          $116                         7.45%
# 59                          $101                         5.99%
# 60                           $90                         2.93%
# 61                           $85                         3.72%
# 62                           $82                             %

# %%
df.columns=['Unna','Historical Data','Historical Data 1','Historical Data 2','Historical Data 3']

# %%
df.columns
# Out:
# Index(['Unna', 'Historical Data', 'Historical Data 1', 'Historical Data 2',
#        'Historical Data 3'],
#       dtype='object')

# %%
df.head(10)
# Out:
#    Unna Historical Data Historical Data 1 Historical Data 2 Historical Data 3
# 0   NaN            Year               GDP        Per Capita            Growth
# 1   0.0            2021        $3,173.40B            $2,277             8.95%
# 2   1.0            2020        $2,667.69B            $1,933            -6.60%
# 3   2.0            2019        $2,831.55B            $2,072             3.74%
# 4   3.0            2018        $2,702.93B            $1,998             6.45%
# 5   4.0            2017        $2,651.47B            $1,981             6.80%
# 6   5.0            2016        $2,294.80B            $1,733             8.26%
# 7   6.0            2015        $2,103.59B            $1,606             8.00%
# 8   7.0            2014        $2,039.13B            $1,574             7.41%
# 9   8.0            2013        $1,856.72B            $1,450             6.39%

# %%
df.isnull().sum()
# Out:
# Unna                 1
# Historical Data      0
# Historical Data 1    0
# Historical Data 2    0
# Historical Data 3    0
# dtype: int64

# %%
df.dropna(axis=0,inplace=True)

# %%
df.isnull().sum()
# Out:
# Unna                 0
# Historical Data      0
# Historical Data 1    0
# Historical Data 2    0
# Historical Data 3    0
# dtype: int64

# %%
df.head(10)
# Out:
#     Unna Historical Data Historical Data 1 Historical Data 2 Historical Data 3
# 1    0.0            2021        $3,173.40B            $2,277             8.95%
# 2    1.0            2020        $2,667.69B            $1,933            -6.60%
# 3    2.0            2019        $2,831.55B            $2,072             3.74%
# 4    3.0            2018        $2,702.93B            $1,998             6.45%
# 5    4.0            2017        $2,651.47B            $1,981             6.80%
# 6    5.0            2016        $2,294.80B            $1,733             8.26%
# 7    6.0            2015        $2,103.59B            $1,606             8.00%
# 8    7.0            2014        $2,039.13B            $1,574             7.41%
# 9    8.0            2013        $1,856.72B            $1,450             6.39%
# 10   9.0            2012        $1,827.64B            $1,444             5.46%

# %%
df.drop(['Unna'], axis=1, inplace=True)

# %%
df
# Out:
#    Historical Data Historical Data 1 Historical Data 2 Historical Data 3
# 1             2021        $3,173.40B            $2,277             8.95%
# 2             2020        $2,667.69B            $1,933            -6.60%
# 3             2019        $2,831.55B            $2,072             3.74%
# 4             2018        $2,702.93B            $1,998             6.45%
# 5             2017        $2,651.47B            $1,981             6.80%
# ..             ...               ...               ...               ...
# 58            1964           $56.48B              $116             7.45%
# 59            1963           $48.42B              $101             5.99%
# 60            1962           $42.16B               $90             2.93%
# 61            1961           $39.23B               $85             3.72%
# 62            1960           $37.03B               $82                 %
#
# [62 rows x 4 columns]

# %% [markdown]
# ## Renaiming columns names

# %%
df.columns=['Year','GDP','Per Capita','Growth']

# %%
df
# Out:
#     Year         GDP Per Capita  Growth
# 1   2021  $3,173.40B     $2,277   8.95%
# 2   2020  $2,667.69B     $1,933  -6.60%
# 3   2019  $2,831.55B     $2,072   3.74%
# 4   2018  $2,702.93B     $1,998   6.45%
# 5   2017  $2,651.47B     $1,981   6.80%
# ..   ...         ...        ...     ...
# 58  1964     $56.48B       $116   7.45%
# 59  1963     $48.42B       $101   5.99%
# 60  1962     $42.16B        $90   2.93%
# 61  1961     $39.23B        $85   3.72%
# 62  1960     $37.03B        $82       %
#
# [62 rows x 4 columns]

# %%
df.dropna(axis=0,inplace=True)

# %%
#Dropping last row
df.drop([df['Year'].count()],axis=0,inplace=True)

# %%
df
# Out:
#     Year         GDP Per Capita  Growth
# 1   2021  $3,173.40B     $2,277   8.95%
# 2   2020  $2,667.69B     $1,933  -6.60%
# 3   2019  $2,831.55B     $2,072   3.74%
# 4   2018  $2,702.93B     $1,998   6.45%
# 5   2017  $2,651.47B     $1,981   6.80%
# ..   ...         ...        ...     ...
# 57  1965     $59.55B       $119  -2.64%
# 58  1964     $56.48B       $116   7.45%
# 59  1963     $48.42B       $101   5.99%
# 60  1962     $42.16B        $90   2.93%
# 61  1961     $39.23B        $85   3.72%
#
# [61 rows x 4 columns]

# %%
df.head(10)
# Out:
#     Year         GDP Per Capita  Growth
# 1   2021  $3,173.40B     $2,277   8.95%
# 2   2020  $2,667.69B     $1,933  -6.60%
# 3   2019  $2,831.55B     $2,072   3.74%
# 4   2018  $2,702.93B     $1,998   6.45%
# 5   2017  $2,651.47B     $1,981   6.80%
# 6   2016  $2,294.80B     $1,733   8.26%
# 7   2015  $2,103.59B     $1,606   8.00%
# 8   2014  $2,039.13B     $1,574   7.41%
# 9   2013  $1,856.72B     $1,450   6.39%
# 10  2012  $1,827.64B     $1,444   5.46%

# %%
df.tail(10)
# Out:
#     Year      GDP Per Capita  Growth
# 52  1970  $62.42B       $112   5.16%
# 53  1969  $58.45B       $108   6.54%
# 54  1968  $53.09B       $100   3.39%
# 55  1967  $50.13B        $96   7.83%
# 56  1966  $45.87B        $90  -0.06%
# 57  1965  $59.55B       $119  -2.64%
# 58  1964  $56.48B       $116   7.45%
# 59  1963  $48.42B       $101   5.99%
# 60  1962  $42.16B        $90   2.93%
# 61  1961  $39.23B        $85   3.72%

# %%
# reversing df for better Matplotlib visualization 
df = df.reindex(index=df.index[::-1])
df.head(10)
# Out:
#     Year      GDP Per Capita  Growth
# 61  1961  $39.23B        $85   3.72%
# 60  1962  $42.16B        $90   2.93%
# 59  1963  $48.42B       $101   5.99%
# 58  1964  $56.48B       $116   7.45%
# 57  1965  $59.55B       $119  -2.64%
# 56  1966  $45.87B        $90  -0.06%
# 55  1967  $50.13B        $96   7.83%
# 54  1968  $53.09B       $100   3.39%
# 53  1969  $58.45B       $108   6.54%
# 52  1970  $62.42B       $112   5.16%

# %% [markdown]
# ## Data cleaning

# %%
years = df['Year'].to_list()
years = list(map(int, years))


def remove_per(str1):
    num = str1.split('%')[0]
    return float(num)

growth = df['Growth'].to_list()
growth = list(map(remove_per, growth))


def cleanGDP(str1):
    str1 = str1.replace('$', '')
    str1 = str1.replace(',', '')
    str1 = str1.replace('B', '')
    num = float(str1)
    return num

gdp = df['GDP'].to_list()
gdp = list(map(cleanGDP, gdp))


per_capita = df['Per Capita'].to_list()
per_capita = list(map(cleanGDP, per_capita))

# %%
# plotting Year wise Growth 
fig, ax = plt.subplots()
ax.plot(years, growth)
plt.xlabel("Years")
plt.ylabel("Growth")
plt.title("**Year Wise Growth**")
plt.show()

# %%
# plot a bar graph for Year wise Growth
fig, ax = plt.subplots()
ax.bar(years, growth, edgecolor="white")
plt.xlabel("Years")
plt.ylabel("Growth")
plt.title("Year wise Growth")
ax.set(xlim=(1960, 2022),
       ylim=(-12,12), yticks=np.arange(-12,12))
plt.show()

# %%
fig, ax = plt.subplots()
ax.bar(years, gdp, edgecolor="white")
plt.xlabel("Years")
plt.ylabel("GDP in Billions($)")
plt.title("Year wise GDP")
plt.show()

# %%
fig, ax = plt.subplots()
ax.bar(years, per_capita, edgecolor="white")
plt.xlabel("Years")
plt.ylabel("Per Capita Income($)")
plt.title("Year wise Per Capita Income")
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(gdp, per_capita)
plt.xlabel("GDP in Billions($)")
plt.ylabel("Per Capita Income($)")
plt.title("GDP vs Per Capita")
plt.show()

# %%
df[df['Growth'] == df['Growth'].min()]
# Out:
#     Year      GDP Per Capita  Growth
# 56  1966  $45.87B        $90  -0.06%

# %%
df.sort_values(by=['Growth']).head(10)
# Out:
#     Year         GDP Per Capita  Growth
# 56  1966     $45.87B        $90  -0.06%
# 50  1972     $71.46B       $123  -0.55%
# 57  1965     $59.55B       $119  -2.64%
# 43  1979    $152.99B       $224  -5.24%
# 2   2020  $2,667.69B     $1,933  -6.60%
# 31  1991    $270.11B       $303   1.06%
# 48  1974     $99.53B       $163   1.19%
# 51  1971     $67.35B       $119   1.64%
# 46  1976    $102.72B       $161   1.66%
# 60  1962     $42.16B        $90   2.93%

# %%
df[df['Growth'] == df['Growth'].max()]
# Out:
#     Year       GDP Per Capita Growth
# 34  1988  $296.59B       $354  9.63%

# %%
df.sort_values(by=['Growth'], ascending=False).head(10)
# Out:
#     Year         GDP Per Capita Growth
# 34  1988    $296.59B       $354  9.63%
# 47  1975     $98.47B       $158  9.15%
# 1   2021  $3,173.40B     $2,277  8.95%
# 23  1999    $458.82B       $442  8.85%
# 12  2010  $1,675.62B     $1,358  8.50%
# 6   2016  $2,294.80B     $1,733  8.26%
# 16  2006    $940.26B       $807  8.06%
# 7   2015  $2,103.59B     $1,606  8.00%
# 18  2004    $709.15B       $628  7.92%
# 17  2005    $820.38B       $715  7.92%

# %%
# Year with highest GDP in Indian History
df[df['GDP'] == df['GDP'].max()]
# Out:
#     Year      GDP Per Capita Growth
# 48  1974  $99.53B       $163  1.19%

# %%
# Top 10 years with higehst GDP 
df.sort_values(by=['GDP'], ascending=False).head(10)
# Out:
#     Year       GDP Per Capita  Growth
# 48  1974   $99.53B       $163   1.19%
# 47  1975   $98.47B       $158   9.15%
# 16  2006  $940.26B       $807   8.06%
# 49  1973   $85.52B       $144   3.30%
# 17  2005  $820.38B       $715   7.92%
# 50  1972   $71.46B       $123  -0.55%
# 18  2004  $709.15B       $628   7.92%
# 51  1971   $67.35B       $119   1.64%
# 52  1970   $62.42B       $112   5.16%
# 19  2003  $607.70B       $547   7.86%

# %%
# Year with highest Per Capita in Indian History
df[df['Per Capita'] == df['Per Capita'].max()]
# Out:
#     Year         GDP Per Capita Growth
# 14  2008  $1,198.90B       $999  3.09%

# %%
# Top 10 years with higehst Per Capita income 
df.sort_values(by=['Per Capita'], ascending=False).head(10)
# Out:
#     Year         GDP Per Capita  Growth
# 14  2008  $1,198.90B       $999   3.09%
# 55  1967     $50.13B        $96   7.83%
# 60  1962     $42.16B        $90   2.93%
# 56  1966     $45.87B        $90  -0.06%
# 61  1961     $39.23B        $85   3.72%
# 16  2006    $940.26B       $807   8.06%
# 17  2005    $820.38B       $715   7.92%
# 18  2004    $709.15B       $628   7.92%
# 19  2003    $607.70B       $547   7.86%
# 20  2002    $514.94B       $471   3.80%
